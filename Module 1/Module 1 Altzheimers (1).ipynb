# %% [markdown]
# # Module_1: *(Alzheimer's Disease)*
#
# ## Team Members:
# *Sydney Schrage & Julena Patel*
#
# ## Project Title:
# *Head Injuries and Alzheimer’s Disease.*

# %% [markdown]
# ## Project Goal:
# We are seeking to computationally and statistically analyze real patient data to gain a deeper understanding about Alzheimer's disease and how it is influenced by previous head injuries.

# %% [markdown]
# ## Disease Background:
# *Fill in information about 11 bullets:*
#
# * Prevalence & incidence
#     - As of 2025 #From Chatgpt
#      Prevalence:
#      ~7.4 million people with Alzheimers diease in the U.S. all age groups
#      2.22% of the total U.S. population
#      Incidence rate:
#      ~500,000 new cases annually
#      0.15% per year
# * Economic burden
#     $305 billion in 2020 (https://pubmed.ncbi.nlm.nih.gov/32840331/)
#     Currently: $360 billion in US... $1.3 trillion worldwide
#     Projection: $1 trillion in US by 2050
#     Medicare and medicaid cover $220 billion per year ~ 61% of total cost
#     Costs: Hospital bill, testing, treatment/medication, long-term care, patients leaving workforce, home modifications & equipment (ChatGPT)
# * Risk factors (genetic, lifestyle)
#     #from Chatgpt
# Genetics:
#   Age:
#     -The strongest known risk factor
#     -Risk doubles every 5 years after age 65
#   Family History:
#     -Parents or Siblings with Alzheimers increases risk
#   Genes:
#   Risk Genes:
#     -APOE-ε4 is the most significant known risk gene; carrying one copy increases risk, and two copies raise it further.
#   Deterministic Genes:
#     -Mutations in APP, PSEN1, and PSEN2 almost always lead to Alzheimer’s.
# Lifestyle and Health-Related RIsk Factors:
#   Cardiovascular Health:
#     -High blood pressure, diabetes, obesity, and high cholesterol
#     -Stroke and heart disease are also linked.
#   Physical Inactivity:
#     -Lack of regular exercise
#   Unhealthy Diet:
#     -High in saturated fats, processed foods, and sugar
#     -Mediterranean and diets rich in vegetables, whole grains, lean proteins, and healthy fats may protect brain health.
#   Smoking & Excess Alcohol:
#     -Smoking damages blood vessels and accelerates cognitive decline.
#     -Heavy alcohol use is neurotoxic
#   Sleep Problems:
#     -Chronic sleep deprivation and sleep apnea are linked to buildup of amyloid plaques.
#   Cognitive & Social Engagement:
#     -Limited mental stimulation, low education, and social isolation are associated with higher risk.
#     -Lifelong learning, mentally challenging activities, and strong social connections may reduce risk.
# Other:
#   Traumatic Brain Injury
#     - Moderate to severe head injuries
#   Depression and Stress:
#     -Possibly due to effects on brain chemistry and inflammation.
#   Environmental factors:
#     -Exposure to air pollution, toxins, or heavy metals
# * Societal determinants
#     Higher risk for...
#         Lower income
#         Lower educaiton- education challenges the brain, building a cognitive reserve that protects the brain from damage
#         Black + Hispanic populations - due to healthcare access, economic factors, existing hypertension/diabetes, stress exposure
#         Limited access to health care - less likely for an early diagnosis and preventative care
#         Environment - less green space, high pollution, less healthy food, less excersize facilities
#         Lower social engagement - social connections protect against cognitive decline
#         Jobs that require less thinking - cognitive reserve needs to be strengthened
#         Cultures - some cultures look down on dimensia, resulting in a delay for seeking help (ChatGPT)
# * Symptoms
# #From CHatgpt
#   Early stage:
#     -Memory loss, trouble finding words, difficulty with daily tasks, disorientation, poor judgment, mood changes.
#   Moderate stage:
#     -Increased memory loss, confusion about time/place, difficulty recognizing people, language problems, wandering, behavioral changes, need for help with self-care.
#   Severe stage:
#     -Loss of communication, inability to recognize loved ones, loss of mobility/swallowing, total dependence, high risk of infections.
# * Diagnosis
#   Source: https://www.mayoclinic.org/diseases-conditions/alzheimers-disease/diagnosis-treatment/drc-20350453
#   They do this by using a combination of tests that may include tests for biomarkers. Biomarkers can detect if plaques and tangles are present in the brain. Biomarker tests include specific types of positron emission tomography, also known as PET, scans of the brain. Amyloid and tau proteins also can be measured in the fluid part of the blood or in the fluid that surrounds the brain and spinal cord, known as cerebrospinal fluid. Recently, blood biomarker tests have become accurate enough to tell if someone is likely to have amyloid in the brain.
#
# Biomarker tests were mainly used in clinical trials until recently. But healthcare professionals have started using them along with other tests to help diagnose Alzheimer's disease. Biomarker tests also can let healthcare professionals know if the disease is in the early or later stages.
# Tests: Physical and neurological exam, Lab tests, mental status and neuropsychological testing, brain imaging(MRI, CT, PET)
# Genetic tests aren't recommended for most people who might have Alzheimer's disease. But people with a family history of early-onset Alzheimer's disease may consider being tested.
# * Standard of care treatments (& reimbursement)
# source: https://www.nia.nih.gov/health/alzheimers-treatment/how-alzheimers-disease-treated
# Medications for mild to moderate Alzheimer’s disease
# Cholinesterase inhibitors: donepezil, rivastigmine, galantamine, and benzgalantamine. These help prevent the breakdown of acetylcholine which supports memory and thinking.
# Immunotherapies (disease-modifying) for early Alzheimer’s: lecanemab and donanemab. These target amyloid β plaques in the brain. Clinical trials have shown that for some people with early Alzheimer’s or mild cognitive impairment, these drugs slow the rate of cognitive decline and reduce amyloid.
# Medications for moderate to severe Alzheimer’s disease
# Memantine, an NMDA receptor antagonist, is used to help with symptoms in moderate to severe stages. It helps regulate glutamate, which in excess can be harmful to brain cells.
# Combination of memantine + donepezil is also approved for moderate to severe cases.
# Reimbursement & Coverage
# Medicare (Part B & Part D)
# Part D generally covers prescription drugs, including traditional symptomatic Alzheimer’s drugs (cholinesterase inhibitors, memantine).
# Part B covers certain medical services (doctor visits, outpatient care), and nowcovers some FDA-approved monoclonal antibody disease-modifying treatments
# Before these therapies can be prescribed, doctors may need to verify that amyloid deposits are present through PET scans or cerebrospinal fluid (CSF) tests
# * Disease progression & prognosis
#   Source: https://www.mayoclinic.org/diseases-conditions/alzheimers-disease/in-depth/alzheimers-stages/art-20048448
#   There are generally five stages associated with Alzheimer's disease:
#     Preclinical Alzheimer's disease.
#       This stage of Alzheimer's can last for years, or even decades. Although you won't notice any changes, new brain-imaging technologies can identify amyloid plaques and neurofibrillary tangles. Tangles develop when proteins called tau change shape and organize into structures.
#     Mild cognitive impairment due to Alzheimer's disease.
#       The short term for mild cognitive impairment is MCI. These mild changes aren't enough to affect work or relationships. People with MCI may have memory lapses when it comes to information that is usually easily remembered. This may include conversations, recent events or appointments.
#
#       People with MCI also may have trouble judging the amount of time needed for a task. They may have trouble figuring out the number or order of steps needed to complete a task. The ability to make good decisions also may become harder.
#     Mild dementia due to Alzheimer's disease.
#       Memory loss of recent events, trouble with problem-solving, complex tasks, and sound judgments, changes in personality, trouble organizing and expressing thoughts, getting lost or misplacing belongings
#     Moderate dementia due to Alzheimer's disease.
#       Show increasingly poor judgement and deepening confusion, experience even greater memory loss, need help with some daily activities, undergo significant changes in personality and behavior
#     Severe dementia due to Alzheimer's disease.
#       Lose the ability to communicate, require daily assistance with personal care, experience a decline in physical abilities
# * Continuum of care providers
# Source: https://www.alzheimers.gov/professionals/health-care-providers
# Several types of health care professionals may be involved with diagnosing and providing care to people with dementia. These include:
# - Primary care doctors
# - Neurologists, who specialize in disorders of the brain and nervous system
# - Geriatricians, who specialize in the care of older adults
# - Geriatric psychiatrists, who specialize in the mental and emotional health of older adults
# - Neuropsychologists, who specialize in standardized assessment of cognition and behavior
# - Clinical psychologists, social workers, and general psychiatrists, who specialize in understanding, diagnosing, and treating mental health and behavior disorders
# - Speech, physical, and occupational therapists, who specialize in improving patients’ ability to communicate and perform self-care activities
# - Nurses
# - Home health aides
# Source: ChatGPT
# Here are a few programs / networks that embody this continuum idea:
# Alzheimer’s Association: Through things like Professional Care Providers, Dementia Care Provider Roundtable, LINC-AD (Long-Term and Community-Based Providers) which bring together home/community-based, long-term, memory care and research stakeholders.
# Alzheimer’s Association
# +2
# Alzheimer’s Association
# +2
# Stanford Health Care’s Collaborative Continuum of Care Model: Follows patients/families through the stages and coordinates between specialists and community services.
# PMC
# NHCA (National Health Care Associates): Offers multiple levels (home care, memory care, skilled nursing, therapy) plus care coordination to manage transitions.
# NHCA
# Universal Home Care (Los Angeles): Their “Continuum Care Program” which helps transition people from hospital to home, coordinates personal care.
# Universal Home Care
#
# * Biological mechanisms (anatomy, organ physiology, cell & molecular physiology)
# Source: https://www.nia.nih.gov/health/alzheimers-causes-and-risk-factors/what-happens-brain-alzheimers-disease
# The brain typically shrinks to some degree in healthy aging, but surprisingly, does not lose neurons in large numbers. In Alzheimer’s, however, damage is widespread, as many neurons stop functioning properly, lose connections with other neurons, and eventually die. Alzheimer’s disrupts processes vital to neurons and their networks, including communication, metabolism, and repair.
#
# At first, Alzheimer’s usually damages the connections among neurons in parts of the brain involved in memory, including the entorhinal cortex and hippocampus. It later affects areas in the cerebral cortex responsible for language, reasoning, and social behavior. Eventually, many other areas of the brain and surrounding neurons are damaged and stop working normally. Over time, a person with Alzheimer’s gradually loses their ability to live and function independently. Ultimately, the disease is fatal.
# Scientists continue to unravel the complex molecular and cellular changes involved in Alzheimer’s and how they lead to the characteristic symptoms of the disease. Because the changes initially affect parts of the brain that are essential for forming new memories, memory problems are typically one of the first signs of cognitive impairment related to Alzheimer’s. Over time, additional parts of the brain are involved, causing worsening problems with thinking, reasoning, and remembering. By the later stages of the disease, damage to the brain becomes so widespread that a person can no longer communicate and is dependent on others for care.
# * Clinical Trials/next-gen therapies
# Source: ChatGPT
# Amyloid vs. Tau vs. Inflammation: Many therapies (e.g. lecanemab, donanemab) target amyloid. But there is growing interest in tau (e.g. posdinemab), immune modulators (NK cell therapy, small molecules), gene therapies, and stem cell/regenerative approaches.
# Earlier Intervention: Trials increasingly target patients at very early or even pre-symptomatic stages (e.g. genetic risk carriers, APOE4 homozygotes). Earlier treatment tends to yield bigger benefits.
# MedPath
# Reddit
# Biomarker use & surrogate endpoints: More use of imaging (PET scans for amyloid/tau), CSF biomarkers, and plasma tests. Also meta-analyses trying to validate that changes in amyloid correlate to clinical benefit.
# arXiv
# MedPath
# Safety & Side Effects: Especially risks like ARIA (amyloid-related imaging abnormalities) are significant for anti-amyloid therapies. Adjusting dosing/titration helps.

# %% [markdown]
# ## Data-Set:
# *(Describe the data set(s) you will analyze. Cite the source(s) of the data.)*
# How was it acquired?
#     The brain tissue used in the study was donated by organ donors.
# When was it acquired?
#     The brain tissue was preserved hours after death from each patient; the average age of death was 88.
# Who was it acquired by?
#     The study was conducted by the BRAIN initiative SEA-AD.
# What techniques were used?
#     Multiomics, spatial genomics, neuropathology, pseudoprogression analysis, mapping, and many other techniques were used.
# What units are the data measured in?
#     The units for the data are picogram / microgram (pg/ug).

# %% [markdown]
# ## Data Analyis:
# *(Describe how you analyzed the data. This is where you should intersperse your Python code so that anyone reading this can run your code to perform the analysis that you did, generate your figures, etc.)*

# %%
# print just headers
import csv

with open ("UpdatedMetaData.csv", newline="") as f:
    reader = csv.reader(f)
    headers = next(reader)
    for h in headers:
        print(h)

# %% [markdown]
# Graphs Age at death vs Known head injury (version 1 just uses the one csv data set)

# %%
# source: ChatGPT
import csv
import matplotlib.pyplot as plt

from collections import defaultdict

# File path
filename = "UpdatedMetaData.csv"

# Dictionary to hold ages grouped by head injury status
groups = defaultdict(list)

# Read CSV
with open(filename, encoding="utf8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        head_injury = row.get("Known head injury", "").strip()
        age_str = row.get("Age at Death", "").strip()

        if head_injury and age_str:  # make sure both values exist
            try:
                age = int(age_str)
                groups[head_injury].append(age)
            except ValueError:
                pass  # skip if age is not an integer

# Compute averages
labels = []
averages = []
for injury_status, ages in groups.items():
    labels.append(injury_status)
    averages.append(sum(ages) / len(ages))

# Plot bar graph
plt.bar(labels, averages, color=["steelblue", "salmon"])
plt.title("Average Age at Death by Head Injury Status")
plt.xlabel("Known Head Injury")
plt.ylabel("Average Age at Death")
plt.tight_layout()
plt.show()

# %% [markdown]
# ![Graph 1](images/Figure_1.png)

# %% [markdown]
# Statistics test for previous graph: (proves that there is no statistically significant difference between age of death and known head injuries)

# %%
import pandas as pd
import scipy.stats as stats

# Load data
rows = []
with open("UpdatedMetaData.csv", encoding="utf8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        if row["Sex"] != "" and row["Age at Death"] != "":
            rows.append({"Sex": row["Sex"], "Age": float(row["Age at Death"])})

df = pd.DataFrame(rows)

# Separate groups
male_ages = df[df["Sex"] == "Male"]["Age"]
female_ages = df[df["Sex"] == "Female"]["Age"]

# Student's t-test (independent, two-tailed, unpaired)
t_stat, p_val = stats.ttest_ind(male_ages, female_ages, equal_var=False)

print("Student's t-test results:")
print(f"T-statistic = {t_stat:.4f}")
print(f"P-value     = {p_val:.4e}")

# Interpretation at alpha = 0.05
alpha = 0.05
if p_val < alpha:
    print(f"Since p < {alpha}, the difference IS statistically significant.")
else:
    print(f"Since p ≥ {alpha}, the difference is NOT statistically significant.")

# %% [markdown]
# Graphs Age of death vs known head injury (version 2 w/ statistics test)

# %%
#claude AI assistance
import csv
import warnings
import matplotlib.pyplot as plt
import numpy as np
import statistics
from termcolor import colored
from scipy import stats



class Patient:

    all_patients = []
    death_age = []
    education_lvl = {}

    def __init__(self, DonorID, ABeta40: float , ABeta42: float, tTau: float, pTau: float):
        self.DonorID = DonorID
        self.ABeta40 = ABeta40
        self.ABeta42 = ABeta42
        self.tTau = tTau
        self.pTau = pTau
        self.sex = None
        self.death_age = None
        self.ed_lvl = None
        self.cog_stat = None
        self.age_symp_on = None
        self.age_diag = None
        self.head_inj = None
        self.thal_score = None
        Patient.all_patients.append(self)

    def __repr__(self):
        return f"{self.DonorID} | sex: {self.sex} | ABeta40 {self.ABeta40} | tTau {self.tTau} | pTau {self.pTau} | Death Age {self.death_age} | Thal Score {self.thal_score}"

    def get_id(self):
        return self.DonorID

    def get_ABeta42(self):
        return self.ABeta42
   
    def get_thal(self):
        return self.thal_score
   
    def get_death_age(self):
        return self.death_age

    @classmethod
    def combine_data(cls, filename: str):
        with open(filename, encoding="utf8") as f:
            reader = csv.DictReader(f)
            rows_of_patients = list(reader)
            #for line in csv create object
            for row in range(len(rows_of_patients)):
                if Patient.all_patients[row].DonorID == rows_of_patients[row]["Donor ID"]:
                    if rows_of_patients[row]["Sex"] != "":
                        Patient.all_patients[row].sex = rows_of_patients[row]["Sex"]

                    if rows_of_patients[row]["Age at Death"] != "":
                        Patient.all_patients[row].death_age = int(rows_of_patients[row]["Age at Death"])

                    if rows_of_patients[row]["Highest level of education"] != "":
                        Patient.all_patients[row].ed_lvl = rows_of_patients[row]["Highest level of education"]

                    if rows_of_patients[row]["Cognitive Status"] != "":
                        Patient.all_patients[row].cog_stat = rows_of_patients[row]["Cognitive Status"]

                    if rows_of_patients[row]["Age of onset cognitive symptoms"] != "":
                        Patient.all_patients[row].age_symp_on = int(rows_of_patients[row]["Age of onset cognitive symptoms"])

                    if rows_of_patients[row]["Age of Dementia diagnosis"] != "":
                        Patient.all_patients[row].age_diag = int(rows_of_patients[row]["Age of Dementia diagnosis"])

                    if rows_of_patients[row]["Known head injury"] != "":
                        Patient.all_patients[row].head_inj = rows_of_patients[row]["Known head injury"]

                    if rows_of_patients[row]["Thal"] != "":
                        Patient.all_patients[row].thal_score = int(rows_of_patients[row]["Thal"].split()[1])
       
                else:
                    warnings.warn("IDs do not match.")

    @classmethod
    def instantiate_from_csv(cls, filename: str, other_file: str):
        #open csv and create list of all rows
        with open(filename, encoding="utf8") as f:
            reader = csv.DictReader(f)
            rows_of_patients = list(reader)
            #for line in csv create object
            for row in rows_of_patients:
                Patient(
                    DonorID = row['Donor ID'],
                    ABeta40 = float(row['ABeta40 pg/ug']),
                    ABeta42 = float(row['ABeta42 pg/ug']),
                    tTau = float(row['tTAU pg/ug']),
                    pTau = float(row['pTAU pg/ug'])
                )
            Patient.all_patients.sort(key = Patient.get_id)
            Patient.combine_data(other_file)

    @classmethod
    def sort_ed(cls):
        for patient in Patient.all_patients:
            Patient.education_lvl.update({patient.ed_lvl: []})
        for patient in Patient.all_patients:
            Patient.education_lvl[patient.ed_lvl].append(patient)

    @classmethod
    def subsort_thal(cls):
        for key in Patient.education_lvl:
            values = Patient.education_lvl.get(key)
            values.sort(key = Patient.get_thal)
            Patient.education_lvl.update({key: values})

    @classmethod
    def filter(cls, list, ABeta40:float ="any", ABeta42:float ="any", tTau:float= "any", pTau:float ="any", sex:str ="any", death_age:int ="any", ed_lvl:str ="any", cog_stat:str ="any", age_symp_on:int ="any", age_diag:int ="any", head_inj:str ="any", thal_score:int ="any"):
        all_patients = list
        remove_list = []
        attr_list = (
                    ABeta40,
                    ABeta42,
                    tTau,
                    pTau,
                    sex,
                    death_age,
                    ed_lvl,
                    cog_stat,
                    age_symp_on,
                    age_diag,
                    head_inj,
                    thal_score
                    )
        attr_name = (
                    "ABeta40",
                    "ABeta42",
                    "tTau",
                    "pTau",
                    "sex",
                    "death_age",
                    "ed_lvl",
                    "cog_stat",
                    "age_symp_on",
                    "age_diag",
                    "head_inj",
                    "thal_score"
                    )
        for attr in range(len(attr_list)):
            if attr_list[attr] != "any":
                for patient in all_patients:
                    if getattr(patient,attr_name[attr]) != attr_list[attr]:
                        remove_list.append(patient)
                all_patients = [patient for patient in all_patients if patient not in remove_list]
                remove_list.clear()
       
        return all_patients


# Main execution code
Patient.instantiate_from_csv('UpdatedLuminex.csv', 'UpdatedMetaData.csv')

for patient in Patient.all_patients:
    print(patient)

Patient.all_patients.sort(key=Patient.get_ABeta42, reverse=False)

for patient in Patient.all_patients:
    print(patient)

Patient.sort_ed()
Patient.subsort_thal()

for key in Patient.education_lvl:
    print(colored(key,"red"))
    for patient in Patient.education_lvl.get(key):
        print(patient)
    print()

fem_healty_patients = range(len(Patient.filter(Patient.all_patients, sex = "Female", cog_stat = "No dementia")))
male_healthy_patients = range(len(Patient.filter(Patient.all_patients, sex = "Male", cog_stat = "No dementia")))
fem_diseased_patients = range(len(Patient.filter(Patient.all_patients, sex = "Female", cog_stat = "Dementia")))
male_diseased_patients = range(len(Patient.filter(Patient.all_patients, sex = "Male", cog_stat = "Dementia")))

print(f'Female Healthy Patients = {len(fem_healty_patients)} | Male Healthy Patients = {len(male_healthy_patients)}')
print(f'Female Diseased Patients = {len(fem_diseased_patients)} | Male Diseased Patients = {len(male_diseased_patients)}')

# Analysis code
age_head_inj_yes = []
age_head_inj_no = []

for patient in Patient.filter(Patient.all_patients, head_inj = "Yes"):
     age_head_inj_yes.append(patient.death_age)
for patient in Patient.filter(Patient.all_patients, head_inj = "No"):
     age_head_inj_no.append(patient.death_age)

x_yes_bar = (statistics.mean(age_head_inj_yes))
x_no_bar = (statistics.mean(age_head_inj_no))

age_yes_stdev = (statistics.stdev(age_head_inj_yes))
age_no_stdev = (statistics.stdev(age_head_inj_no))

print (f'head injury yes stdv: ', {age_yes_stdev})
print(f'head injury yes mean: ',{ x_yes_bar} )
print(f'head injury no stdv: ' ,{ age_no_stdev })
print(f'head injury no mean: ', {x_no_bar} )

print(f'x_yes_bar = {x_yes_bar}, age_yes_stdev {age_yes_stdev}')
print(f'x_no_bar = {x_no_bar}, age_no_stdev {age_no_stdev}')

x_yes_vals = range(len(Patient.filter(Patient.all_patients, head_inj = "Yes")))
x_no_vals = range(len(Patient.filter(Patient.all_patients, head_inj = "No")))

sex_cols = ['Yes', 'No']
mean_sex_ABeta42 = [x_yes_bar, x_no_bar]
stdev_sex_ABeta42 = [age_yes_stdev, age_no_stdev]

# Equal variance assumed
t_stat, p_val = stats.ttest_ind(age_head_inj_yes, age_head_inj_no)
print("t-statistic:", t_stat)
print("p-value:", p_val)

plt.bar(sex_cols, mean_sex_ABeta42, yerr=stdev_sex_ABeta42, capsize=10, color=["red", "blue"])
plt.title("Age of Death by Known Head Injury")
plt.xlabel("Known Head Injury")
plt.ylabel("Age of Death")
plt.show()

# shows that head injury does not have a significant effect on age at death
# Out:
# H19.33.004 | sex: Female | ABeta40 0.019621053 | tTau 1552.414737 | pTau 1.901052632 | Death Age 80 | Thal Score 0
# H20.33.001 | sex: Male | ABeta40 0.215789474 | tTau 756.0905263 | pTau 2.737894737 | Death Age 82 | Thal Score 2
# H20.33.002 | sex: Female | ABeta40 0.000597895 | tTau 313.5252632 | pTau 2.615789474 | Death Age 97 | Thal Score 0
# H20.33.004 | sex: Male | ABeta40 60.76631579 | tTau 318.5284211 | pTau 7.412631579 | Death Age 86 | Thal Score 5
# H20.33.005 | sex: Female | ABeta40 5.136842105 | tTau 107.3484211 | pTau 1.327368421 | Death Age 99 | Thal Score 3
# H20.33.008 | sex: Female | ABeta40 3.991578947 | tTau 125.9336842 | pTau 2.569473684 | Death Age 92 | Thal Score 4
# H20.33.011 | sex: Female | ABeta40 11.84526316 | tTau 1141.492355 | pTau 8.536842105 | Death Age 93 | Thal Score 5
# H20.33.012 | sex: Female | ABeta40 2.529473684 | tTau 950.7410526 | pTau 4.545263158 | Death Age 91 | Thal Score 1
# ...

# %% [markdown]
# Code for graph that plots age of diagnosis vs known head injury

# %%
# Claude AI assistance
import csv
import warnings
import matplotlib.pyplot as plt
import numpy as np
import statistics
from termcolor import colored
from scipy import stats


class Patient:

    all_patients = []
    death_age = []
    education_lvl = {}

    def __init__(self, DonorID, ABeta40: float , ABeta42: float, tTau: float, pTau: float):
        self.DonorID = DonorID
        self.ABeta40 = ABeta40
        self.ABeta42 = ABeta42
        self.tTau = tTau
        self.pTau = pTau
        self.sex = None
        self.death_age = None
        self.ed_lvl = None
        self.cog_stat = None
        self.age_symp_on = None
        self.age_diag = None
        self.head_inj = None
        self.thal_score = None
        Patient.all_patients.append(self)

    def __repr__(self):
        return f"{self.DonorID} | sex: {self.sex} | ABeta40 {self.ABeta40} | tTau {self.tTau} | pTau {self.pTau} | Death Age {self.death_age} | Thal Score {self.thal_score} | Head Injury: {self.head_inj} | Age at Diagnosis: {self.age_diag}"

    def get_id(self):
        return self.DonorID

    def get_ABeta42(self):
        return self.ABeta42
   
    def get_thal(self):
        return self.thal_score
   
    def get_death_age(self):
        return self.death_age
   
    def get_age_diag(self):
        return self.age_diag

    @classmethod
    def combine_data(cls, filename: str):
        with open(filename, encoding="utf8") as f:
            reader = csv.DictReader(f)
            rows_of_patients = list(reader)
            #for line in csv create object
            for row in range(len(rows_of_patients)):
                if Patient.all_patients[row].DonorID == rows_of_patients[row]["Donor ID"]:
                    if rows_of_patients[row]["Sex"] != "":
                        Patient.all_patients[row].sex = rows_of_patients[row]["Sex"]

                    if rows_of_patients[row]["Age at Death"] != "":
                        Patient.all_patients[row].death_age = int(rows_of_patients[row]["Age at Death"])

                    if rows_of_patients[row]["Highest level of education"] != "":
                        Patient.all_patients[row].ed_lvl = rows_of_patients[row]["Highest level of education"]

                    if rows_of_patients[row]["Cognitive Status"] != "":
                        Patient.all_patients[row].cog_stat = rows_of_patients[row]["Cognitive Status"]

                    if rows_of_patients[row]["Age of onset cognitive symptoms"] != "":
                        Patient.all_patients[row].age_symp_on = int(rows_of_patients[row]["Age of onset cognitive symptoms"])

                    if rows_of_patients[row]["Age of Dementia diagnosis"] != "":
                        Patient.all_patients[row].age_diag = int(rows_of_patients[row]["Age of Dementia diagnosis"])

                    if rows_of_patients[row]["Known head injury"] != "":
                        Patient.all_patients[row].head_inj = rows_of_patients[row]["Known head injury"]

                    if rows_of_patients[row]["Thal"] != "":
                        Patient.all_patients[row].thal_score = int(rows_of_patients[row]["Thal"].split()[1])
       
                else:
                    warnings.warn("IDs do not match.")

    @classmethod
    def instantiate_from_csv(cls, filename: str, other_file: str):
        #open csv and create list of all rows
        with open(filename, encoding="utf8") as f:
            reader = csv.DictReader(f)
            rows_of_patients = list(reader)
            #for line in csv create object
            for row in rows_of_patients:
                Patient(
                    DonorID = row['Donor ID'],
                    ABeta40 = float(row['ABeta40 pg/ug']),
                    ABeta42 = float(row['ABeta42 pg/ug']),
                    tTau = float(row['tTAU pg/ug']),
                    pTau = float(row['pTAU pg/ug'])
                )
            Patient.all_patients.sort(key = Patient.get_id)
            Patient.combine_data(other_file)

    @classmethod
    def filter(cls, list, ABeta40:float ="any", ABeta42:float ="any", tTau:float= "any", pTau:float ="any", sex:str ="any", death_age:int ="any", ed_lvl:str ="any", cog_stat:str ="any", age_symp_on:int ="any", age_diag:int ="any", head_inj:str ="any", thal_score:int ="any"):
        all_patients = list
        remove_list = []
        attr_list = (
                    ABeta40,
                    ABeta42,
                    tTau,
                    pTau,
                    sex,
                    death_age,
                    ed_lvl,
                    cog_stat,
                    age_symp_on,
                    age_diag,
                    head_inj,
                    thal_score
                    )
        attr_name = (
                    "ABeta40",
                    "ABeta42",
                    "tTau",
                    "pTau",
                    "sex",
                    "death_age",
                    "ed_lvl",
                    "cog_stat",
                    "age_symp_on",
                    "age_diag",
                    "head_inj",
                    "thal_score"
                    )
        for attr in range(len(attr_list)):
            if attr_list[attr] != "any":
                for patient in all_patients:
                    if getattr(patient,attr_name[attr]) != attr_list[attr]:
                        remove_list.append(patient)
                all_patients = [patient for patient in all_patients if patient not in remove_list]
                remove_list.clear()
       
        return all_patients


# Main execution code
Patient.instantiate_from_csv('UpdatedLuminex.csv', 'UpdatedMetaData.csv')

print("Total patients loaded:", len(Patient.all_patients))

# Filter for patients who have dementia diagnosis and age of diagnosis data
patients_with_diagnosis = [p for p in Patient.all_patients if p.age_diag is not None and p.head_inj is not None]

print(f"Patients with diagnosis age and head injury data: {len(patients_with_diagnosis)}")

# Separate patients by head injury status
age_diag_head_inj_yes = []
age_diag_head_inj_no = []

for patient in patients_with_diagnosis:
    if patient.head_inj == "Yes":
        age_diag_head_inj_yes.append(patient.age_diag)
    elif patient.head_inj == "No":
        age_diag_head_inj_no.append(patient.age_diag)

print(f"Patients with head injury (Yes): {len(age_diag_head_inj_yes)}")
print(f"Patients with no head injury (No): {len(age_diag_head_inj_no)}")

if len(age_diag_head_inj_yes) > 0 and len(age_diag_head_inj_no) > 0:
    # Calculate statistics
    mean_age_diag_yes = statistics.mean(age_diag_head_inj_yes)
    mean_age_diag_no = statistics.mean(age_diag_head_inj_no)

    stdev_age_diag_yes = statistics.stdev(age_diag_head_inj_yes) if len(age_diag_head_inj_yes) > 1 else 0
    stdev_age_diag_no = statistics.stdev(age_diag_head_inj_no) if len(age_diag_head_inj_no) > 1 else 0

    print(f'Head injury Yes - Mean age at diagnosis: {mean_age_diag_yes:.2f}, Std dev: {stdev_age_diag_yes:.2f}')
    print(f'Head injury No - Mean age at diagnosis: {mean_age_diag_no:.2f}, Std dev: {stdev_age_diag_no:.2f}')

    # Statistical test
    if len(age_diag_head_inj_yes) > 1 and len(age_diag_head_inj_no) > 1:
        t_stat, p_val = stats.ttest_ind(age_diag_head_inj_yes, age_diag_head_inj_no)
        print(f"t-statistic: {t_stat:.4f}")
        print(f"p-value: {p_val:.4f}")

    # Create the bar chart
    head_inj_categories = ['Yes', 'No']
    mean_ages = [mean_age_diag_yes, mean_age_diag_no]
    stdev_ages = [stdev_age_diag_yes, stdev_age_diag_no]

    plt.figure(figsize=(10, 6))
    bars = plt.bar(head_inj_categories, mean_ages, yerr=stdev_ages, capsize=10,
                   color=["red", "blue"], alpha=0.7, edgecolor='black')

    plt.title("Age of Diagnosis by Known Head Injury", fontsize=14, fontweight='bold')
    plt.xlabel("Known Head Injury", fontsize=12)
    plt.ylabel("Age of Diagnosis", fontsize=12)
    plt.ylim(0, max(mean_ages) + max(stdev_ages) + 10)
   
    # Add grid for better readability
    plt.grid(axis='y', alpha=0.3, linestyle='--')
   
    plt.tight_layout()
    plt.show()

else:
    print("Insufficient data to create meaningful comparison")
    print("Age diagnosis data available for head injury groups:")
    print(f"Yes: {age_diag_head_inj_yes}")
    print(f"No: {age_diag_head_inj_no}")
# Out:
# Total patients loaded: 84
# Patients with diagnosis age and head injury data: 13
# Patients with head injury (Yes): 6
# Patients with no head injury (No): 7
# Head injury Yes - Mean age at diagnosis: 82.00, Std dev: 11.51
# Head injury No - Mean age at diagnosis: 78.57, Std dev: 13.79
# t-statistic: 0.4813
# p-value: 0.6398

# %% [markdown]
# Scatterplot age of death and years of education + export data as AgeEducationData.csv + regression plot

# %%
# AGE OF DEATH VS YEARS OF EDUCATION SCATTERPLOT
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "UpdatedMetaData.csv"  # adjust if needed
df = pd.read_csv(file_path)

# Extract relevant columns and drop rows with missing values
plot_data = df[['Age at Death', 'Years of education']].dropna()

# Create scatter plot
plt.figure(figsize=(8,6))
plt.scatter(plot_data['Years of education'], plot_data['Age at Death'], alpha=0.6)
plt.title("Scatterplot of Age at Death vs. Years of Education")
plt.xlabel("Years of Education")
plt.ylabel("Age at Death")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()


# CSV EXPORT
# Load dataset
file_path = "UpdatedMetaData.csv"  # adjust if needed
df = pd.read_csv(file_path)

# Select relevant columns and drop missing values
export_data = df[['Age at Death', 'Years of education']].dropna()

# Save to new CSV file
export_data.to_csv("AgeEducationData.csv", index=False)

print("Data exported to AgeEducationData.csv")

#REGRESSION
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

df = pd.read_csv("AgeEducationData.csv")
x = df["Age at Death"].values.reshape(-1, 1)
y = df["Years of education"].values

model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]
intercept = model.intercept_
r2 = model.score(x, y)

plt.scatter(x, y, color='blue')
plt.plot(x, model.predict(x), color="red")
# Annotate equation
equation = f"y = {slope:.2f}x + {intercept:.2f}\nR² = {r2:.2f}"
plt.text(x.min(), y.max(), equation, color="red", fontsize=12, verticalalignment='top')
# Annotate scatterplot with labels and title
plt.xlabel("Age at Death")
plt.ylabel("Years of education")
plt.title("Age at Death vs. Years of education")
plt.show()
# Out:
# Data exported to AgeEducationData.csv

# %% [markdown]
# ## Verify and validate your analysis:
# *(Describe how you checked to see that your analysis gave you an answer that you believe (verify). Describe how your determined if your analysis gave you an answer that is supported by other evidence (e.g., a published paper).*
# Both of our graphs appear counterintuitive, since individuals with known head injuries are generally considered more likely to develop Alzheimer’s as well as experience earlier death due to Alzheimer’s-related health concerns (Pneumonia, Malnutrition, Infection). We were not anticipating these results because we already did research on the impact head injuries have on Alzheimer's disease patients.
# According to an article published on PubMed, it states that “Researchers found that any medical history of head injury more than doubled both the risk of developing Alzheimer's Disease and the chance of developing non-Alzheimer's dementia”. Additionally, the Mayo Clinic reported that “people with Alzheimer's disease live between three and 11 years after diagnosis”
# When we compare our findings to published research, the results are not consistent. Prior studies suggest that head injuries significantly increase the risk of Alzheimer’s, while our data did not show a statistically significant difference in the age of diagnosis between those with and without head injuries, nor did it reveal a difference in age at death. This discrepancy may be due to various limitations.

# %% [markdown]
# ## Conclusions and Ethical Implications:
# *(Think about the answer your analysis generated, draw conclusions related to your overarching question, and discuss the ethical implications of your conclusions.*
# Based on graphs, we can conclude that previous known head injuries do not have a significant impact on age of diagnosis and death for Alzheimer's disease patients. Results contradict research, proving that the relationship between head injuries and Alzheimer's disease progression is complex and needs to be studied more thoroughly.
# Patients may feel reassured knowing that head injuries do not appear to significantly affect the age of diagnosis or overall lifespan in individuals with Alzheimer’s disease.​
#     Stress reliever- less stakes
# Doctors may place less emphasis on head injuries as a predictor of Alzheimer’s disease, since they do not appear to greatly influence Alzheimer’s-related mortality.​
# Hospitals may screen for head injuries less​
# Insurers may prioritize other risk factors to cover, including factors where we can find concrete data evidence that suggests there is a direct correlation between the risk factor and head injuries. It would be unjustified for insurance companies to use head injury status to determine insurance when it does not significantly impact Alzheimer's diagnosis or death.
# ** approach all these claims with caution due to the inconsistency we had with research and data results. These are all ethical implications based on the data we analyzed.

# %% [markdown]
# ## Limitations and Future Work:
# Limitations:
# - small data set, only within a specific age range
# - confounding variables such as APOE genes or other health concerns may have skewed the data
#     - this is why we can't prove causation from correlation
# - limited head injury information - just the yes or no
#
# Future work: Our original idea was to compare the gender, head injuries, and alzheimer's disease progression. We quickly realized that these were too many variables, so we eliminated the gender portion. If we were to continue with this research, we would love to incorporate it back in. We are interested to see how sex affects whether or not someone is more likely to have a known head injury, and how it will consequently affect Alzheimer's disease progression.
# We want to look at a wider data set​ next time in order to get more accurate results that may align better with our research.
# We also want to look into how severe their previous head injuries actually were and impact of repeated head injuries. This requires more data collection but would allow us to make more graphs and draw more connections.

# %% [markdown]
# ## Class Notes:
#  Brainstorm questions:
#    Are specific races more prone to developing alzheimer's disease?
#     How do level of education and occupation increase the risk of alzheimer's disease?
#     If you have an APOE gen, are you more prone to an earlier death?
#     Do previous head injuries lead to an increased risk of alzheimer's disease? How does this vary and compare between men and women?
#     Do men or women die earlier from Alzheimer's (after they are diagnosed)?
#     If you don't have easy access to healthcare, does the disease progess faster?
# We picked "Do previous head injuries lead to an increased risk of alzheimer's disease? How does this vary and compare between men and women?" to do our project on.
# We decided that our question was too complex with too many variables, so we decided to eliminate the gender portion and just focus on head injuries as it relates to altzheimers progression and death due to the disease.

# %% [markdown]
# ## Questions for TA:
# None at the moment :)
